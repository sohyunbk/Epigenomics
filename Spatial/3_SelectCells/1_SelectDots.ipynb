# %%
def get_row_name_by_spatial_coordinates(Meta, x_value, y_value):
    selected_row = Meta[(Meta['spatial_x'] == x_value) & (Meta['spatial_y'] == y_value)]
    # Check if a row is found
    if not selected_row.empty:
        row_name = selected_row.index[0]
        print(row_name)
    else:
        return None  # Return None if no matching row is found

# %%
# A619-C
adata = sc.read_h5ad('/Users/sohyun/Documents/2.SingleCellATAC/12.Spatial/2.h5adFiles/A619_B_adata_processed.h5ad')
fig = px.scatter(x=adata.obsm['spatial'][:, 0], y=adata.obsm['spatial'][:, 1])

# Invert the y-axis
fig.update_layout(
    yaxis=dict(autorange='reversed'),
    width=800,  # Set the width of the figure
    height=800  # Set the height of the figure (increased to make it longer)
)

fig.show()
Meta = adata.obs
Meta['spatial_x'] = adata.obsm['spatial'][:, 0]
Meta['spatial_y'] = adata.obsm['spatial'][:, 1]

#selected_row = Meta[(Meta['spatial_x'] == 2142) & (Meta['spatial_y'] == 4356)]
#row_name = selected_row.index[0]
#print(row_name)
get_row_name_by_spatial_coordinates(Meta, 2142, 4356)
get_row_name_by_spatial_coordinates(Meta, 2236, 4356)
get_row_name_by_spatial_coordinates(Meta, 2230, 4356)
get_row_name_by_spatial_coordinates(Meta, 2424, 4357)
get_row_name_by_spatial_coordinates(Meta, 4868, 3873)
get_row_name_by_spatial_coordinates(Meta, 4914, 3954)
get_row_name_by_spatial_coordinates(Meta, 4961, 3873)
get_row_name_by_spatial_coordinates(Meta, 4727, 3791)
# Out:
# GCATTGTAATTCATAT-1
# AGCTTGATCTTAACTT-1
# CGCCTGGCCTACGTAA-1
# AAACGAGACGGTTGAT-1
# AAGAGGCATGGATCGC-1
# ATAACGCCGGAGGGTC-1
# TTGAATATGGACTTTC-1

# %%
# A619-C
adata = sc.read_h5ad('/Users/sohyun/Documents/2.SingleCellATAC/12.Spatial/2.h5adFiles/A619_C_adata_processed.h5ad')
fig = px.scatter(x=adata.obsm['spatial'][:, 0], y=adata.obsm['spatial'][:, 1])

# Invert the y-axis
fig.update_layout(
    yaxis=dict(autorange='reversed'),
    width=800,  # Set the width of the figure
    height=800  # Set the height of the figure (increased to make it longer)
)

fig.show()
Meta = adata.obs
Meta['spatial_x'] = adata.obsm['spatial'][:, 0]
Meta['spatial_y'] = adata.obsm['spatial'][:, 1]

#selected_row = Meta[(Meta['spatial_x'] == 2142) & (Meta['spatial_y'] == 4356)]
#row_name = selected_row.index[0]
#print(row_name)
get_row_name_by_spatial_coordinates(Meta, 2230, 3946)
get_row_name_by_spatial_coordinates(Meta, 2324, 3946)
get_row_name_by_spatial_coordinates(Meta, 2277, 4028)
get_row_name_by_spatial_coordinates(Meta, 2371, 4028)
get_row_name_by_spatial_coordinates(Meta, 5900, 4606)
get_row_name_by_spatial_coordinates(Meta, 5853, 4524)
get_row_name_by_spatial_coordinates(Meta, 5947, 4524)
get_row_name_by_spatial_coordinates(Meta, 1616, 5173)
get_row_name_by_spatial_coordinates(Meta, 1710, 5174)
get_row_name_by_spatial_coordinates(Meta, 6228, 5507)
get_row_name_by_spatial_coordinates(Meta, 6275, 5589)
# Out:
# TCGTATTACCCATTGC-1
# GGCGCAGGACATCTTC-1
# ATCCTGAATCGCTGCG-1
# ATAAATATTAGCAGCT-1
# CATGATGGAAGTTAGC-1
# AGTGAACAAACTTCTC-1
# AAGTGCCTTGACTGTA-1
# CCCAGTAAACTTGGGA-1
# AGAAGGTACACTTCAC-1
# GTAACATCTAAGATAA-1
# CCGACAATAGGCCGCC-1

# %%
# A619-D
adata = sc.read_h5ad('/Users/sohyun/Documents/2.SingleCellATAC/12.Spatial/2.h5adFiles/A619_D_adata_processed.h5ad')
fig = px.scatter(x=adata.obsm['spatial'][:, 0], y=adata.obsm['spatial'][:, 1])

# Invert the y-axis
fig.update_layout(
    yaxis=dict(autorange='reversed'),
    width=800,  # Set the width of the figure
    height=800  # Set the height of the figure (increased to make it longer)
)

fig.show()

Meta = adata.obs
Meta['spatial_x'] = adata.obsm['spatial'][:, 0]
Meta['spatial_y'] = adata.obsm['spatial'][:, 1]

#selected_row = Meta[(Meta['spatial_x'] == 2142) & (Meta['spatial_y'] == 4356)]
#row_name = selected_row.index[0]
#print(row_name)
get_row_name_by_spatial_coordinates(Meta, 4564, 1705)
get_row_name_by_spatial_coordinates(Meta, 4612, 1789)
get_row_name_by_spatial_coordinates(Meta, 4563, 1873)

get_row_name_by_spatial_coordinates(Meta, 4659, 3720)
get_row_name_by_spatial_coordinates(Meta, 4707, 3804)
get_row_name_by_spatial_coordinates(Meta, 4756, 3888)
# Out:
# AGGTACGATATTGCCA-1
# TTAAGCCGACAACTTC-1
# CCATAAACAACCCGAC-1
# ACTCGTCAGTAATCCC-1
# GGTGATAAGGAGCAGT-1
# CTTGTTGCTGAGTCAA-1
